# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Load original spreadsheets
ROOT = Path(__file__).resolve()
print(f"Root path: {ROOT}")
DATA = "data"

df1 = pd.read_excel(f'{DATA}/file1.xlsx')
